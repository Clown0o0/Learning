# %% [markdown]
# <a href="https://colab.research.google.com/github/Clown0o0/Learning/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 69.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.2
#     Uninstalling pygit2-1.18.2:
#       Successfully uninstalled pygit2-1.18.2
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6730, done.
# remote: Total 6730 (delta 0), reused 0 (delta 0), pack-reused 6730 (from 1)
# Receiving objects: 100% (6730/6730), 33.35 MiB | 14.31 MiB/s, done.
# Resolving deltas: 100% (3847/3847), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.12.11 (main, Jun  4 2025, 08:56:18) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# ...
